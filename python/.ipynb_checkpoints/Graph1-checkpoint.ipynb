# %%
import pandas as pd
import altair as alt
import os

# %%
os.chdir("/Volumes/UBC/Block5/551/Project_MDS/dashboard-project-cryptocurrency_db")

# %%
source1 = pd.read_csv("price.csv")
source1 = source1[(source1.Name == 'bitcoin_cash')]
source1.head()
# Out:
#    Unnamed: 0          Date    Open    High     Low   Close     Volume  \
# 0         212  Jul 23, 2017  555.89  578.97  411.78  413.06     85,013
# 1         211  Jul 24, 2017  412.58  578.89  409.21  440.70    190,952
# 2         210  Jul 25, 2017  441.35  541.66  338.09  406.90    524,908
# 3         209  Jul 26, 2017  407.08  486.16  321.79  365.82  1,784,640
# 4         208  Jul 27, 2017  417.10  460.97  367.78  385.48    533,207
#
#   Market Cap          Name Month_Name  Month_Number  Date_Number  Year  \
# 0          -  bitcoin_cash        Jul             7           23  2017
# 1          -  bitcoin_cash        Jul             7           24  2017
# 2          -  bitcoin_cash        Jul             7           25  2017
# 3          -  bitcoin_cash        Jul             7           26  2017
# 4          -  bitcoin_cash        Jul             7           27  2017
#
#    New_date   New_date1  RollingAvg3_Open  RollingAvg3_Close  \
# 0  20170723  2017-07-23               NaN                NaN
# 1  20170724  2017-07-24               NaN                NaN
# 2  20170725  2017-07-25        469.940000         420.220000
# 3  20170726  2017-07-26        420.336667         404.473333
# 4  20170727  2017-07-27        421.843333         386.066667
#
#    RollingAvg7_Open  RollingAvg7_Close
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN

# %%
alt.data_transformers.disable_max_rows()

base_close = alt.Chart(source1).mark_bar(size=5).encode(
    x=alt.X('New_date1', sort='x'),
    y=alt.Y('Close'),
    color=alt.value("#BABABA"),
    opacity=alt.value(0.8)
)

three_days_rolling_closemean_line = alt.Chart(source1).mark_line().encode(
    x=alt.X('New_date1', sort='x'),
    y=alt.Y('RollingAvg3_Close'),
    color=alt.value("#FFB319")
)

seven_days_rolling_closemean_line = alt.Chart(source1).mark_line().encode(
    x=alt.X('New_date1', sort='x'),
    y=alt.Y('RollingAvg7_Close'),
    color=alt.value("#FFDD99")
)

unique_cryptocurrency = source1['Name'].unique()
data_start = source1['New_date1'].min()
data_end = source1['New_date1'].max()


#778899

# %%
(base_close + three_days_rolling_closemean_line + seven_days_rolling_closemean_line).configure_axis(
    grid=False
).properties(
    width=1400,
    height=300
)
# Out:
# alt.LayerChart(...)
