# %%
# import all packages here

import pandas as pd
import math
import altair as alt
import os
import datetime
from time import strptime

# %%
def crptocurrency_data():
    #Set working directory - Afreen
    os.chdir("/Volumes/UBC/Block5/551/Project_MDS/dashboard-project-cryptocurrency_db")

    # bitcoin_cash_price
    bitcoin_cash_price = pd.read_csv("raw_data/bitcoin_cash_price.csv")
    bitcoin_cash_price['Name']='bitcoin_cash'

    # Fix Date
    bitcoin_cash_price['Month_Name'] = bitcoin_cash_price['Date'].str[:3]
    bitcoin_cash_price['Month_Number'] = 0
    bitcoin_cash_price['Date_Number'] = bitcoin_cash_price['Date'].str[4:6]
    bitcoin_cash_price['Year'] = bitcoin_cash_price['Date'].str[8:12]
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "May", 'Month_Number'] = 5
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    bitcoin_cash_price.loc[bitcoin_cash_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    bitcoin_cash_price['Date_Number'] = bitcoin_cash_price['Date_Number'].astype(int)
    bitcoin_cash_price['Year'] = bitcoin_cash_price['Year'].astype(int)
    bitcoin_cash_price['New_date']=(bitcoin_cash_price['Year']*10000)+(bitcoin_cash_price['Month_Number']*100)+(bitcoin_cash_price['Date_Number'])
    bitcoin_cash_price['New_date1']=pd.to_datetime(bitcoin_cash_price['New_date'], format='%Y%m%d')
    bitcoin_cash_price = bitcoin_cash_price[(bitcoin_cash_price.New_date >= 20170221)]
    bitcoin_cash_price['YYYYMM']=(bitcoin_cash_price['Year']*100)+(bitcoin_cash_price['Month_Number'])

    # Sort dates
    bitcoin_cash_price = bitcoin_cash_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    bitcoin_cash_price['RollingAvg3_Open'] = round(bitcoin_cash_price.Open.rolling(3).mean(),1)
    bitcoin_cash_price['RollingAvg3_Close'] = round(bitcoin_cash_price.Close.rolling(3).mean(),1)
    bitcoin_cash_price['RollingAvg7_Open'] = round(bitcoin_cash_price.Open.rolling(7).mean(),1)
    bitcoin_cash_price['RollingAvg7_Close'] = round(bitcoin_cash_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    bitcoin_cash_price = bitcoin_cash_price.fillna(0)
    
    bitcoin_cash_price['Daily_Diff']=bitcoin_cash_price['Close']-bitcoin_cash_price['Open']
    bitcoin_cash_price.loc[bitcoin_cash_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    bitcoin_cash_price.loc[bitcoin_cash_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    bitcoin_cash_price1 = bitcoin_cash_price[['Date', 'New_date', 'New_date1', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    bitcoin_cash_price1 = bitcoin_cash_price1.rename(columns={"Open": "bitcoin_Cash_OPEN", "High": "bitcoin_Cash_HIGH", "Low": "bitcoin_Cash_LOW", "Close": "bitcoin_Cash_CLOSE", "Volume": "bitcoin_Cash_Volume", "Market Cap": "bitcoin_Cash_MarketCap", "RollingAvg3_Open": "bitcoin_cash_MAvg_Open", "RollingAvg3_Close": "bitcoin_cash_MAvg_Close", 'Direction': "bitcoin_Cash_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # bitcoin_price
    bitcoin_price = pd.read_csv("raw_data/bitcoin_price.csv")
    bitcoin_price['Name']='bitcoin'

    # Fix Date
    bitcoin_price['Month_Name'] = bitcoin_price['Date'].str[:3]
    bitcoin_price['Month_Number'] = 0
    bitcoin_price['Date_Number'] = bitcoin_price['Date'].str[4:6]
    bitcoin_price['Year'] = bitcoin_price['Date'].str[8:12]
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "May", 'Month_Number'] = 5
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    bitcoin_price.loc[bitcoin_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    bitcoin_price['Date_Number'] = bitcoin_price['Date_Number'].astype(int)
    bitcoin_price['Year'] = bitcoin_price['Year'].astype(int)
    bitcoin_price['New_date']=(bitcoin_price['Year']*10000)+(bitcoin_price['Month_Number']*100)+(bitcoin_price['Date_Number'])
    bitcoin_price['New_date1']=pd.to_datetime(bitcoin_price['New_date'], format='%Y%m%d')
    bitcoin_price = bitcoin_price[(bitcoin_price.New_date >= 20170221)]
    bitcoin_price['YYYYMM']=(bitcoin_price['Year']*100)+(bitcoin_price['Month_Number'])

    # Sort dates
    bitcoin_price = bitcoin_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    bitcoin_price['RollingAvg3_Open'] = round(bitcoin_price.Open.rolling(3).mean(),1)
    bitcoin_price['RollingAvg3_Close'] = round(bitcoin_price.Close.rolling(3).mean(),1)
    bitcoin_price['RollingAvg7_Open'] = round(bitcoin_price.Open.rolling(7).mean(),1)
    bitcoin_price['RollingAvg7_Close'] = round(bitcoin_price.Close.rolling(7).mean(),1)

    # Difference b/w open and close
    bitcoin_price = bitcoin_price.fillna(0)

    bitcoin_price['Daily_Diff']=bitcoin_price['Close']-bitcoin_price['Open']
    bitcoin_price.loc[bitcoin_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    bitcoin_price.loc[bitcoin_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"

    # Renaming columns
    bitcoin_price1 = bitcoin_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction']]
    bitcoin_price1 = bitcoin_price1.rename(columns={"Open": "bitcoin_OPEN", "High": "bitcoin_HIGH", "Low": "bitcoin_LOW", "Close": "bitcoin_CLOSE", "Volume": "bitcoin_Volume", "Market Cap": "bitcoin_MarketCap", "RollingAvg3_Open": "bitcoin_MAvg_Open", "RollingAvg3_Close": "bitcoin_MAvg_Close", "Direction": 'bitcoin_Direction'})

    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # bitconnect_price
    bitconnect_price = pd.read_csv("raw_data/bitconnect_price.csv")
    bitconnect_price['Name']='bitconnect'

    # Fix Date
    bitconnect_price['Month_Name'] = bitconnect_price['Date'].str[:3]
    bitconnect_price['Month_Number'] = 0
    bitconnect_price['Date_Number'] = bitconnect_price['Date'].str[4:6]
    bitconnect_price['Year'] = bitconnect_price['Date'].str[8:12]
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "May", 'Month_Number'] = 5
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    bitconnect_price.loc[bitconnect_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    bitconnect_price['Date_Number'] = bitconnect_price['Date_Number'].astype(int)
    bitconnect_price['Year'] = bitconnect_price['Year'].astype(int)
    bitconnect_price['New_date']=(bitconnect_price['Year']*10000)+(bitconnect_price['Month_Number']*100)+(bitconnect_price['Date_Number'])
    bitconnect_price['New_date1']=pd.to_datetime(bitconnect_price['New_date'], format='%Y%m%d')
    bitconnect_price = bitconnect_price[(bitconnect_price.New_date >= 20170221)]
    bitconnect_price['YYYYMM']=(bitconnect_price['Year']*100)+(bitconnect_price['Month_Number'])

    # Sort dates
    bitconnect_price = bitconnect_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    bitconnect_price['RollingAvg3_Open'] = round(bitconnect_price.Open.rolling(3).mean(),1)
    bitconnect_price['RollingAvg3_Close'] = round(bitconnect_price.Close.rolling(3).mean(),1)
    bitconnect_price['RollingAvg7_Open'] = round(bitconnect_price.Open.rolling(7).mean(),1)
    bitconnect_price['RollingAvg7_Close'] = round(bitconnect_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    bitconnect_price = bitconnect_price.fillna(0)
    
    bitconnect_price['Daily_Diff']=bitconnect_price['Close']-bitconnect_price['Open']
    bitconnect_price.loc[bitconnect_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    bitconnect_price.loc[bitconnect_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    bitconnect_price1 = bitconnect_price[['Date', 'New_date', 'New_date1', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    bitconnect_price1 = bitconnect_price1.rename(columns={"Open": "bitconnect_OPEN", "High": "bitconnect_HIGH", "Low": "bitconnect_LOW", "Close": "bitconnect_CLOSE", "Volume": "bitconnect_Volume", "Market Cap": "bitconnect_MarketCap", "RollingAvg3_Open": "bitconnect_MAvg_Open", "RollingAvg3_Close": "bitconnect_MAvg_Close", 'Direction': "bitconnect_Direction"})
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # dash_price
    dash_price = pd.read_csv("raw_data/dash_price.csv")
    dash_price['Name']='dash'

    # Fix Date
    dash_price['Month_Name'] = dash_price['Date'].str[:3]
    dash_price['Month_Number'] = 0
    dash_price['Date_Number'] = dash_price['Date'].str[4:6]
    dash_price['Year'] = dash_price['Date'].str[8:12]
    dash_price.loc[dash_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    dash_price.loc[dash_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    dash_price.loc[dash_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    dash_price.loc[dash_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    dash_price.loc[dash_price['Month_Name'] == "May", 'Month_Number'] = 5
    dash_price.loc[dash_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    dash_price.loc[dash_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    dash_price.loc[dash_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    dash_price.loc[dash_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    dash_price.loc[dash_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    dash_price.loc[dash_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    dash_price.loc[dash_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    dash_price['Date_Number'] = dash_price['Date_Number'].astype(int)
    dash_price['Year'] = dash_price['Year'].astype(int)
    dash_price['New_date']=(dash_price['Year']*10000)+(dash_price['Month_Number']*100)+(dash_price['Date_Number'])
    dash_price['New_date1']=pd.to_datetime(dash_price['New_date'], format='%Y%m%d')
    dash_price = dash_price[(dash_price.New_date >= 20170221)]
    dash_price['YYYYMM']=(dash_price['Year']*100)+(dash_price['Month_Number'])

    # Sort dates
    dash_price = dash_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    dash_price['RollingAvg3_Open'] = round(dash_price.Open.rolling(3).mean(),1)
    dash_price['RollingAvg3_Close'] = round(dash_price.Close.rolling(3).mean(),1)
    dash_price['RollingAvg7_Open'] = round(dash_price.Open.rolling(7).mean(),1)
    dash_price['RollingAvg7_Close'] = round(dash_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    dash_price = dash_price.fillna(0)
    
    dash_price['Daily_Diff']=dash_price['Close']-dash_price['Open']
    dash_price.loc[dash_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    dash_price.loc[dash_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    dash_price1 = dash_price[['Date', 'New_date', 'New_date1', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    dash_price1 = dash_price1.rename(columns={"Open": "dash_OPEN", "High": "dash_HIGH", "Low": "dash_LOW", "Close": "dash_CLOSE", "Volume": "dash_Volume", "Market Cap": "dash_MarketCap", "RollingAvg3_Open": "dash_MAvg_Open", "RollingAvg3_Close": "dash_MAvg_Close", 'Direction': "dash_Direction"})
    
    # ethereum_classic_price
    ethereum_classic_price = pd.read_csv("raw_data/ethereum_classic_price.csv")
    ethereum_classic_price['Name']='ethereum_classic'

    # Fix Date
    ethereum_classic_price['Month_Name'] = ethereum_classic_price['Date'].str[:3]
    ethereum_classic_price['Month_Number'] = 0
    ethereum_classic_price['Date_Number'] = ethereum_classic_price['Date'].str[4:6]
    ethereum_classic_price['Year'] = ethereum_classic_price['Date'].str[8:12]
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "May", 'Month_Number'] = 5
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    ethereum_classic_price.loc[ethereum_classic_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    ethereum_classic_price['Date_Number'] = ethereum_classic_price['Date_Number'].astype(int)
    ethereum_classic_price['Year'] = ethereum_classic_price['Year'].astype(int)
    ethereum_classic_price['New_date']=(ethereum_classic_price['Year']*10000)+(ethereum_classic_price['Month_Number']*100)+(ethereum_classic_price['Date_Number'])
    ethereum_classic_price['New_date1']=pd.to_datetime(ethereum_classic_price['New_date'], format='%Y%m%d')
    ethereum_classic_price = ethereum_classic_price[(ethereum_classic_price.New_date >= 20170221)]
    ethereum_classic_price['YYYYMM']=(ethereum_classic_price['Year']*100)+(ethereum_classic_price['Month_Number'])

    # Sort dates
    ethereum_classic_price = ethereum_classic_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    ethereum_classic_price['RollingAvg3_Open'] = round(ethereum_classic_price.Open.rolling(3).mean(),1)
    ethereum_classic_price['RollingAvg3_Close'] = round(ethereum_classic_price.Close.rolling(3).mean(),1)
    ethereum_classic_price['RollingAvg7_Open'] = round(ethereum_classic_price.Open.rolling(7).mean(),1)
    ethereum_classic_price['RollingAvg7_Close'] = round(ethereum_classic_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    ethereum_classic_price = ethereum_classic_price.fillna(0)
    
    ethereum_classic_price['Daily_Diff']=ethereum_classic_price['Close']-ethereum_classic_price['Open']
    ethereum_classic_price.loc[ethereum_classic_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    ethereum_classic_price.loc[ethereum_classic_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    ethereum_classic_price1 = ethereum_classic_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    ethereum_classic_price1 = ethereum_classic_price1.rename(columns={"Open": "ethereum_classic_OPEN", "High": "ethereum_classic_HIGH", "Low": "ethereum_classic_LOW", "Close": "ethereum_classic_CLOSE", "Volume": "ethereum_classic_Volume", "Market Cap": "ethereum_classic_MarketCap", "RollingAvg3_Open": "ethereum_classic_MAvg_Open", "RollingAvg3_Close": "ethereum_classic_MAvg_Close", 'Direction': "ethereum_classic_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # ethereum_price
    ethereum_price = pd.read_csv("raw_data/ethereum_price.csv")
    ethereum_price['Name']='ethereum'

    # Fix Date
    ethereum_price['Month_Name'] = ethereum_price['Date'].str[:3]
    ethereum_price['Month_Number'] = 0
    ethereum_price['Date_Number'] = ethereum_price['Date'].str[4:6]
    ethereum_price['Year'] = ethereum_price['Date'].str[8:12]
    ethereum_price.loc[ethereum_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    ethereum_price.loc[ethereum_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    ethereum_price.loc[ethereum_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    ethereum_price.loc[ethereum_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    ethereum_price.loc[ethereum_price['Month_Name'] == "May", 'Month_Number'] = 5
    ethereum_price.loc[ethereum_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    ethereum_price.loc[ethereum_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    ethereum_price.loc[ethereum_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    ethereum_price.loc[ethereum_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    ethereum_price.loc[ethereum_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    ethereum_price.loc[ethereum_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    ethereum_price.loc[ethereum_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    ethereum_price['Date_Number'] = ethereum_price['Date_Number'].astype(int)
    ethereum_price['Year'] = ethereum_price['Year'].astype(int)
    ethereum_price['New_date']=(ethereum_price['Year']*10000)+(ethereum_price['Month_Number']*100)+(ethereum_price['Date_Number'])
    ethereum_price['New_date1']=pd.to_datetime(ethereum_price['New_date'], format='%Y%m%d')
    ethereum_price = ethereum_price[(ethereum_price.New_date >= 20170221)]
    ethereum_price['YYYYMM']=(ethereum_price['Year']*100)+(ethereum_price['Month_Number'])

    # Sort dates
    ethereum_price = ethereum_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    ethereum_price['RollingAvg3_Open'] = round(ethereum_price.Open.rolling(3).mean(),1)
    ethereum_price['RollingAvg3_Close'] = round(ethereum_price.Close.rolling(3).mean(),1)
    ethereum_price['RollingAvg7_Open'] = round(ethereum_price.Open.rolling(7).mean(),1)
    ethereum_price['RollingAvg7_Close'] = round(ethereum_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    ethereum_price = ethereum_price.fillna(0)
    
    ethereum_price['Daily_Diff']=ethereum_price['Close']-ethereum_price['Open']
    ethereum_price.loc[ethereum_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    ethereum_price.loc[ethereum_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    ethereum_price1 = ethereum_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    ethereum_price1 = ethereum_price1.rename(columns={"Open": "ethereum_OPEN", "High": "ethereum_HIGH", "Low": "ethereum_LOW", "Close": "ethereum_CLOSE", "Volume": "ethereum_Volume", "Market Cap": "ethereum_MarketCap", "RollingAvg3_Open": "ethereum_MAvg_Open", "RollingAvg3_Close": "ethereum_MAvg_Close", 'Direction': "ethereum_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # iota_price
    iota_price = pd.read_csv("raw_data/iota_price.csv")
    iota_price['Name']='iota'

    # Fix Date
    iota_price['Month_Name'] = iota_price['Date'].str[:3]
    iota_price['Month_Number'] = 0
    iota_price['Date_Number'] = iota_price['Date'].str[4:6]
    iota_price['Year'] = iota_price['Date'].str[8:12]
    iota_price.loc[iota_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    iota_price.loc[iota_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    iota_price.loc[iota_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    iota_price.loc[iota_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    iota_price.loc[iota_price['Month_Name'] == "May", 'Month_Number'] = 5
    iota_price.loc[iota_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    iota_price.loc[iota_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    iota_price.loc[iota_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    iota_price.loc[iota_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    iota_price.loc[iota_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    iota_price.loc[iota_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    iota_price.loc[iota_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    iota_price['Date_Number'] = iota_price['Date_Number'].astype(int)
    iota_price['Year'] = iota_price['Year'].astype(int)
    iota_price['New_date']=(iota_price['Year']*10000)+(iota_price['Month_Number']*100)+(iota_price['Date_Number'])
    iota_price['New_date1']=pd.to_datetime(iota_price['New_date'], format='%Y%m%d')
    iota_price = iota_price[(iota_price.New_date >= 20170221)]
    iota_price['YYYYMM']=(iota_price['Year']*100)+(iota_price['Month_Number'])

    # Sort dates
    iota_price = iota_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    iota_price['RollingAvg3_Open'] = round(iota_price.Open.rolling(3).mean(),1)
    iota_price['RollingAvg3_Close'] = round(iota_price.Close.rolling(3).mean(),1)
    iota_price['RollingAvg7_Open'] = round(iota_price.Open.rolling(7).mean(),1)
    iota_price['RollingAvg7_Close'] = round(iota_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    iota_price = iota_price.fillna(0)
    
    iota_price['Daily_Diff']=iota_price['Close']-iota_price['Open']
    iota_price.loc[iota_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    iota_price.loc[iota_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    iota_price1 = iota_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    iota_price1 = iota_price1.rename(columns={"Open": "iota_OPEN", "High": "iota_HIGH", "Low": "iota_LOW", "Close": "iota_CLOSE", "Volume": "iota_Volume", "Market Cap": "iota_MarketCap", "RollingAvg3_Open": "iota_MAvg_Open", "RollingAvg3_Close": "iota_MAvg_Close", 'Direction': "iota_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # litecoin_price
    litecoin_price = pd.read_csv("raw_data/litecoin_price.csv")
    litecoin_price['Name']='litecoin'

    # Fix Date
    litecoin_price['Month_Name'] = litecoin_price['Date'].str[:3]
    litecoin_price['Month_Number'] = 0
    litecoin_price['Date_Number'] = litecoin_price['Date'].str[4:6]
    litecoin_price['Year'] = litecoin_price['Date'].str[8:12]
    litecoin_price.loc[litecoin_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    litecoin_price.loc[litecoin_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    litecoin_price.loc[litecoin_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    litecoin_price.loc[litecoin_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    litecoin_price.loc[litecoin_price['Month_Name'] == "May", 'Month_Number'] = 5
    litecoin_price.loc[litecoin_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    litecoin_price.loc[litecoin_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    litecoin_price.loc[litecoin_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    litecoin_price.loc[litecoin_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    litecoin_price.loc[litecoin_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    litecoin_price.loc[litecoin_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    litecoin_price.loc[litecoin_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    litecoin_price['Date_Number'] = litecoin_price['Date_Number'].astype(int)
    litecoin_price['Year'] = litecoin_price['Year'].astype(int)
    litecoin_price['New_date']=(litecoin_price['Year']*10000)+(litecoin_price['Month_Number']*100)+(litecoin_price['Date_Number'])
    litecoin_price['New_date1']=pd.to_datetime(litecoin_price['New_date'], format='%Y%m%d')
    litecoin_price = litecoin_price[(litecoin_price.New_date >= 20170221)]
    litecoin_price['YYYYMM']=(litecoin_price['Year']*100)+(litecoin_price['Month_Number'])

    # Sort dates
    litecoin_price = litecoin_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    litecoin_price['RollingAvg3_Open'] = round(litecoin_price.Open.rolling(3).mean(),1)
    litecoin_price['RollingAvg3_Close'] = round(litecoin_price.Close.rolling(3).mean(),1)
    litecoin_price['RollingAvg7_Open'] = round(litecoin_price.Open.rolling(7).mean(),1)
    litecoin_price['RollingAvg7_Close'] = round(litecoin_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    litecoin_price = litecoin_price.fillna(0)
    
    litecoin_price['Daily_Diff']=litecoin_price['Close']-litecoin_price['Open']
    litecoin_price.loc[litecoin_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    litecoin_price.loc[litecoin_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    litecoin_price1 = litecoin_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    litecoin_price1 = litecoin_price1.rename(columns={"Open": "litecoin_OPEN", "High": "litecoin_HIGH", "Low": "litecoin_LOW", "Close": "litecoin_CLOSE", "Volume": "litecoin_Volume", "Market Cap": "litecoin_MarketCap", "RollingAvg3_Open": "litecoin_MAvg_Open", "RollingAvg3_Close": "litecoin_MAvg_Close", 'Direction': "litecoin_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # monero_price
    monero_price = pd.read_csv("raw_data/monero_price.csv")
    monero_price['Name']='monero'

    # Fix Date
    monero_price['Month_Name'] = monero_price['Date'].str[:3]
    monero_price['Month_Number'] = 0
    monero_price['Date_Number'] = monero_price['Date'].str[4:6]
    monero_price['Year'] = monero_price['Date'].str[8:12]
    monero_price.loc[monero_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    monero_price.loc[monero_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    monero_price.loc[monero_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    monero_price.loc[monero_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    monero_price.loc[monero_price['Month_Name'] == "May", 'Month_Number'] = 5
    monero_price.loc[monero_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    monero_price.loc[monero_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    monero_price.loc[monero_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    monero_price.loc[monero_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    monero_price.loc[monero_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    monero_price.loc[monero_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    monero_price.loc[monero_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    monero_price['Date_Number'] = monero_price['Date_Number'].astype(int)
    monero_price['Year'] = monero_price['Year'].astype(int)
    monero_price['New_date']=(monero_price['Year']*10000)+(monero_price['Month_Number']*100)+(monero_price['Date_Number'])
    monero_price['New_date1']=pd.to_datetime(monero_price['New_date'], format='%Y%m%d')
    monero_price = monero_price[(monero_price.New_date >= 20170221)]
    monero_price['YYYYMM']=(monero_price['Year']*100)+(monero_price['Month_Number'])

    # Sort dates
    monero_price = monero_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    monero_price['RollingAvg3_Open'] = round(monero_price.Open.rolling(3).mean(),1)
    monero_price['RollingAvg3_Close'] = round(monero_price.Close.rolling(3).mean(),1)
    monero_price['RollingAvg7_Open'] = round(monero_price.Open.rolling(7).mean(),1)
    monero_price['RollingAvg7_Close'] = round(monero_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    monero_price = monero_price.fillna(0)
    
    monero_price['Daily_Diff']=monero_price['Close']-monero_price['Open']
    monero_price.loc[monero_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    monero_price.loc[monero_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    monero_price1 = monero_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    monero_price1 = monero_price1.rename(columns={"Open": "monero_OPEN", "High": "monero_HIGH", "Low": "monero_LOW", "Close": "monero_CLOSE", "Volume": "monero_Volume", "Market Cap": "monero_MarketCap", "RollingAvg3_Open": "monero_MAvg_Open", "RollingAvg3_Close": "monero_MAvg_Close", 'Direction': "monero_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # nem_price
    nem_price = pd.read_csv("raw_data/nem_price.csv")
    nem_price['Name']='nem'

    # Fix Date
    nem_price['Month_Name'] = nem_price['Date'].str[:3]
    nem_price['Month_Number'] = 0
    nem_price['Date_Number'] = nem_price['Date'].str[4:6]
    nem_price['Year'] = nem_price['Date'].str[8:12]
    nem_price.loc[nem_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    nem_price.loc[nem_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    nem_price.loc[nem_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    nem_price.loc[nem_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    nem_price.loc[nem_price['Month_Name'] == "May", 'Month_Number'] = 5
    nem_price.loc[nem_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    nem_price.loc[nem_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    nem_price.loc[nem_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    nem_price.loc[nem_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    nem_price.loc[nem_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    nem_price.loc[nem_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    nem_price.loc[nem_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    nem_price['Date_Number'] = nem_price['Date_Number'].astype(int)
    nem_price['Year'] = nem_price['Year'].astype(int)
    nem_price['New_date']=(nem_price['Year']*10000)+(nem_price['Month_Number']*100)+(nem_price['Date_Number'])
    nem_price['New_date1']=pd.to_datetime(nem_price['New_date'], format='%Y%m%d')
    nem_price = nem_price[(nem_price.New_date >= 20170221)]
    nem_price['YYYYMM']=(nem_price['Year']*100)+(nem_price['Month_Number'])

    # Sort dates
    nem_price = nem_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    nem_price['RollingAvg3_Open'] = round(nem_price.Open.rolling(3).mean(),1)
    nem_price['RollingAvg3_Close'] = round(nem_price.Close.rolling(3).mean(),1)
    nem_price['RollingAvg7_Open'] = round(nem_price.Open.rolling(7).mean(),1)
    nem_price['RollingAvg7_Close'] = round(nem_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    nem_price = nem_price.fillna(0)
    
    nem_price['Daily_Diff']=nem_price['Close']-nem_price['Open']
    nem_price.loc[nem_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    nem_price.loc[nem_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    nem_price1 = nem_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    nem_price1 = nem_price1.rename(columns={"Open": "nem_OPEN", "High": "nem_HIGH", "Low": "nem_LOW", "Close": "nem_CLOSE", "Volume": "nem_Volume", "Market Cap": "nem_MarketCap", "RollingAvg3_Open": "nem_MAvg_Open", "RollingAvg3_Close": "nem_MAvg_Close", 'Direction': "nem_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # neo_price
    neo_price = pd.read_csv("raw_data/neo_price.csv")
    neo_price['Name']='neo'

    # Fix Date
    neo_price['Month_Name'] = neo_price['Date'].str[:3]
    neo_price['Month_Number'] = 0
    neo_price['Date_Number'] = neo_price['Date'].str[4:6]
    neo_price['Year'] = neo_price['Date'].str[8:12]
    neo_price.loc[neo_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    neo_price.loc[neo_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    neo_price.loc[neo_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    neo_price.loc[neo_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    neo_price.loc[neo_price['Month_Name'] == "May", 'Month_Number'] = 5
    neo_price.loc[neo_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    neo_price.loc[neo_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    neo_price.loc[neo_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    neo_price.loc[neo_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    neo_price.loc[neo_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    neo_price.loc[neo_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    neo_price.loc[neo_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    neo_price['Date_Number'] = neo_price['Date_Number'].astype(int)
    neo_price['Year'] = neo_price['Year'].astype(int)
    neo_price['New_date']=(neo_price['Year']*10000)+(neo_price['Month_Number']*100)+(neo_price['Date_Number'])
    neo_price['New_date1']=pd.to_datetime(neo_price['New_date'], format='%Y%m%d')
    neo_price = neo_price[(neo_price.New_date >= 20170221)]
    neo_price['YYYYMM']=(neo_price['Year']*100)+(neo_price['Month_Number'])

    # Sort dates
    neo_price = neo_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    neo_price['RollingAvg3_Open'] = round(neo_price.Open.rolling(3).mean(),1)
    neo_price['RollingAvg3_Close'] = round(neo_price.Close.rolling(3).mean(),1)
    neo_price['RollingAvg7_Open'] = round(neo_price.Open.rolling(7).mean(),1)
    neo_price['RollingAvg7_Close'] = round(neo_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    neo_price = neo_price.fillna(0)
    
    neo_price['Daily_Diff']=neo_price['Close']-neo_price['Open']
    neo_price.loc[neo_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    neo_price.loc[neo_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    neo_price1 = neo_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    neo_price1 = neo_price1.rename(columns={"Open": "neo_OPEN", "High": "neo_HIGH", "Low": "neo_LOW", "Close": "neo_CLOSE", "Volume": "neo_Volume", "Market Cap": "neo_MarketCap", "RollingAvg3_Open": "neo_MAvg_Open", "RollingAvg3_Close": "neo_MAvg_Close", 'Direction': "neo_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # numeraire_price
    numeraire_price = pd.read_csv("raw_data/numeraire_price.csv")
    numeraire_price['Name']='numeraire'

    # Fix Date
    numeraire_price['Month_Name'] = numeraire_price['Date'].str[:3]
    numeraire_price['Month_Number'] = 0
    numeraire_price['Date_Number'] = numeraire_price['Date'].str[4:6]
    numeraire_price['Year'] = numeraire_price['Date'].str[8:12]
    numeraire_price.loc[numeraire_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    numeraire_price.loc[numeraire_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    numeraire_price.loc[numeraire_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    numeraire_price.loc[numeraire_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    numeraire_price.loc[numeraire_price['Month_Name'] == "May", 'Month_Number'] = 5
    numeraire_price.loc[numeraire_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    numeraire_price.loc[numeraire_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    numeraire_price.loc[numeraire_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    numeraire_price.loc[numeraire_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    numeraire_price.loc[numeraire_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    numeraire_price.loc[numeraire_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    numeraire_price.loc[numeraire_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    numeraire_price['Date_Number'] = numeraire_price['Date_Number'].astype(int)
    numeraire_price['Year'] = numeraire_price['Year'].astype(int)
    numeraire_price['New_date']=(numeraire_price['Year']*10000)+(numeraire_price['Month_Number']*100)+(numeraire_price['Date_Number'])
    numeraire_price['New_date1']=pd.to_datetime(numeraire_price['New_date'], format='%Y%m%d')
    numeraire_price = numeraire_price[(numeraire_price.New_date >= 20170221)]
    numeraire_price['YYYYMM']=(numeraire_price['Year']*100)+(numeraire_price['Month_Number'])

    # Sort dates
    numeraire_price = numeraire_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    numeraire_price['RollingAvg3_Open'] = round(numeraire_price.Open.rolling(3).mean(),1)
    numeraire_price['RollingAvg3_Close'] = round(numeraire_price.Close.rolling(3).mean(),1)
    numeraire_price['RollingAvg7_Open'] = round(numeraire_price.Open.rolling(7).mean(),1)
    numeraire_price['RollingAvg7_Close'] = round(numeraire_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    numeraire_price = numeraire_price.fillna(0)
    
    numeraire_price['Daily_Diff']=numeraire_price['Close']-numeraire_price['Open']
    numeraire_price.loc[numeraire_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    numeraire_price.loc[numeraire_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    numeraire_price1 = numeraire_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    numeraire_price1 = numeraire_price1.rename(columns={"Open": "numeraire_OPEN", "High": "numeraire_HIGH", "Low": "numeraire_LOW", "Close": "numeraire_CLOSE", "Volume": "numeraire_Volume", "Market Cap": "numeraire_MarketCap", "RollingAvg3_Open": "numeraire_MAvg_Open", "RollingAvg3_Close": "numeraire_MAvg_Close", 'Direction': "numeraire_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # omisego_price
    omisego_price = pd.read_csv("raw_data/omisego_price.csv")
    omisego_price['Name']='omisego'

    # Fix Date
    omisego_price['Month_Name'] = omisego_price['Date'].str[:3]
    omisego_price['Month_Number'] = 0
    omisego_price['Date_Number'] = omisego_price['Date'].str[4:6]
    omisego_price['Year'] = omisego_price['Date'].str[8:12]
    omisego_price.loc[omisego_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    omisego_price.loc[omisego_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    omisego_price.loc[omisego_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    omisego_price.loc[omisego_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    omisego_price.loc[omisego_price['Month_Name'] == "May", 'Month_Number'] = 5
    omisego_price.loc[omisego_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    omisego_price.loc[omisego_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    omisego_price.loc[omisego_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    omisego_price.loc[omisego_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    omisego_price.loc[omisego_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    omisego_price.loc[omisego_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    omisego_price.loc[omisego_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    omisego_price['Date_Number'] = omisego_price['Date_Number'].astype(int)
    omisego_price['Year'] = omisego_price['Year'].astype(int)
    omisego_price['New_date']=(omisego_price['Year']*10000)+(omisego_price['Month_Number']*100)+(omisego_price['Date_Number'])
    omisego_price['New_date1']=pd.to_datetime(omisego_price['New_date'], format='%Y%m%d')
    omisego_price = omisego_price[(omisego_price.New_date >= 20170221)]
    omisego_price['YYYYMM']=(omisego_price['Year']*100)+(omisego_price['Month_Number'])

    # Sort dates
    omisego_price = omisego_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    omisego_price['RollingAvg3_Open'] = round(omisego_price.Open.rolling(3).mean(),1)
    omisego_price['RollingAvg3_Close'] = round(omisego_price.Close.rolling(3).mean(),1)
    omisego_price['RollingAvg7_Open'] = round(omisego_price.Open.rolling(7).mean(),1)
    omisego_price['RollingAvg7_Close'] = round(omisego_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    omisego_price = omisego_price.fillna(0)
    
    omisego_price['Daily_Diff']=omisego_price['Close']-omisego_price['Open']
    omisego_price.loc[omisego_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    omisego_price.loc[omisego_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    omisego_price1 = omisego_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    omisego_price1 = omisego_price1.rename(columns={"Open": "omisego_OPEN", "High": "omisego_HIGH", "Low": "omisego_LOW", "Close": "omisego_CLOSE", "Volume": "omisego_Volume", "Market Cap": "omisego_MarketCap", "RollingAvg3_Open": "omisego_MAvg_Open", "RollingAvg3_Close": "omisego_MAvg_Close", 'Direction': "omisego_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # qtum_price
    qtum_price = pd.read_csv("raw_data/qtum_price.csv")
    qtum_price['Name']='qtum'

    # Fix Date
    qtum_price['Month_Name'] = qtum_price['Date'].str[:3]
    qtum_price['Month_Number'] = 0
    qtum_price['Date_Number'] = qtum_price['Date'].str[4:6]
    qtum_price['Year'] = qtum_price['Date'].str[8:12]
    qtum_price.loc[qtum_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    qtum_price.loc[qtum_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    qtum_price.loc[qtum_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    qtum_price.loc[qtum_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    qtum_price.loc[qtum_price['Month_Name'] == "May", 'Month_Number'] = 5
    qtum_price.loc[qtum_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    qtum_price.loc[qtum_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    qtum_price.loc[qtum_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    qtum_price.loc[qtum_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    qtum_price.loc[qtum_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    qtum_price.loc[qtum_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    qtum_price.loc[qtum_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    qtum_price['Date_Number'] = qtum_price['Date_Number'].astype(int)
    qtum_price['Year'] = qtum_price['Year'].astype(int)
    qtum_price['New_date']=(qtum_price['Year']*10000)+(qtum_price['Month_Number']*100)+(qtum_price['Date_Number'])
    qtum_price['New_date1']=pd.to_datetime(qtum_price['New_date'], format='%Y%m%d')
    qtum_price = qtum_price[(qtum_price.New_date >= 20170221)]
    qtum_price['YYYYMM']=(qtum_price['Year']*100)+(qtum_price['Month_Number'])

    # Sort dates
    qtum_price = qtum_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    qtum_price['RollingAvg3_Open'] = round(qtum_price.Open.rolling(3).mean(),1)
    qtum_price['RollingAvg3_Close'] = round(qtum_price.Close.rolling(3).mean(),1)
    qtum_price['RollingAvg7_Open'] = round(qtum_price.Open.rolling(7).mean(),1)
    qtum_price['RollingAvg7_Close'] = round(qtum_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    qtum_price = qtum_price.fillna(0)
    
    qtum_price['Daily_Diff']=qtum_price['Close']-qtum_price['Open']
    qtum_price.loc[qtum_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    qtum_price.loc[qtum_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    qtum_price1 = qtum_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    qtum_price1 = qtum_price1.rename(columns={"Open": "qtum_OPEN", "High": "qtum_HIGH", "Low": "qtum_LOW", "Close": "qtum_CLOSE", "Volume": "qtum_Volume", "Market Cap": "qtum_MarketCap", "RollingAvg3_Open": "qtum_MAvg_Open", "RollingAvg3_Close": "qtum_MAvg_Close", 'Direction': "qtum_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # ripple_price
    ripple_price = pd.read_csv("raw_data/ripple_price.csv")
    ripple_price['Name']='ripple'

    # Fix Date
    ripple_price['Month_Name'] = ripple_price['Date'].str[:3]
    ripple_price['Month_Number'] = 0
    ripple_price['Date_Number'] = ripple_price['Date'].str[4:6]
    ripple_price['Year'] = ripple_price['Date'].str[8:12]
    ripple_price.loc[ripple_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    ripple_price.loc[ripple_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    ripple_price.loc[ripple_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    ripple_price.loc[ripple_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    ripple_price.loc[ripple_price['Month_Name'] == "May", 'Month_Number'] = 5
    ripple_price.loc[ripple_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    ripple_price.loc[ripple_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    ripple_price.loc[ripple_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    ripple_price.loc[ripple_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    ripple_price.loc[ripple_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    ripple_price.loc[ripple_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    ripple_price.loc[ripple_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    ripple_price['Date_Number'] = ripple_price['Date_Number'].astype(int)
    ripple_price['Year'] = ripple_price['Year'].astype(int)
    ripple_price['New_date']=(ripple_price['Year']*10000)+(ripple_price['Month_Number']*100)+(ripple_price['Date_Number'])
    ripple_price['New_date1']=pd.to_datetime(ripple_price['New_date'], format='%Y%m%d')
    ripple_price = ripple_price[(ripple_price.New_date >= 20170221)]
    ripple_price['YYYYMM']=(ripple_price['Year']*100)+(ripple_price['Month_Number'])

    # Sort dates
    ripple_price = ripple_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    ripple_price['RollingAvg3_Open'] = round(ripple_price.Open.rolling(3).mean(),1)
    ripple_price['RollingAvg3_Close'] = round(ripple_price.Close.rolling(3).mean(),1)
    ripple_price['RollingAvg7_Open'] = round(ripple_price.Open.rolling(7).mean(),1)
    ripple_price['RollingAvg7_Close'] = round(ripple_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    ripple_price = ripple_price.fillna(0)
    
    ripple_price['Daily_Diff']=ripple_price['Close']-ripple_price['Open']
    ripple_price.loc[ripple_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    ripple_price.loc[ripple_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    ripple_price1 = ripple_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    ripple_price1 = ripple_price1.rename(columns={"Open": "ripple_OPEN", "High": "ripple_HIGH", "Low": "ripple_LOW", "Close": "ripple_CLOSE", "Volume": "ripple_Volume", "Market Cap": "ripple_MarketCap", "RollingAvg3_Open": "ripple_MAvg_Open", "RollingAvg3_Close": "ripple_MAvg_Close", 'Direction': "ripple_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # stratis_price
    stratis_price = pd.read_csv("raw_data/stratis_price.csv")
    stratis_price['Name']='stratis'

    # Fix Date
    stratis_price['Month_Name'] = stratis_price['Date'].str[:3]
    stratis_price['Month_Number'] = 0
    stratis_price['Date_Number'] = stratis_price['Date'].str[4:6]
    stratis_price['Year'] = stratis_price['Date'].str[8:12]
    stratis_price.loc[stratis_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    stratis_price.loc[stratis_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    stratis_price.loc[stratis_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    stratis_price.loc[stratis_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    stratis_price.loc[stratis_price['Month_Name'] == "May", 'Month_Number'] = 5
    stratis_price.loc[stratis_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    stratis_price.loc[stratis_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    stratis_price.loc[stratis_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    stratis_price.loc[stratis_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    stratis_price.loc[stratis_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    stratis_price.loc[stratis_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    stratis_price.loc[stratis_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    stratis_price['Date_Number'] = stratis_price['Date_Number'].astype(int)
    stratis_price['Year'] = stratis_price['Year'].astype(int)
    stratis_price['New_date']=(stratis_price['Year']*10000)+(stratis_price['Month_Number']*100)+(stratis_price['Date_Number'])
    stratis_price['New_date1']=pd.to_datetime(stratis_price['New_date'], format='%Y%m%d')
    stratis_price = stratis_price[(stratis_price.New_date >= 20170221)]
    stratis_price['YYYYMM']=(stratis_price['Year']*100)+(stratis_price['Month_Number'])

    # Sort dates
    stratis_price = stratis_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    stratis_price['RollingAvg3_Open'] = round(stratis_price.Open.rolling(3).mean(),1)
    stratis_price['RollingAvg3_Close'] = round(stratis_price.Close.rolling(3).mean(),1)
    stratis_price['RollingAvg7_Open'] = round(stratis_price.Open.rolling(7).mean(),1)
    stratis_price['RollingAvg7_Close'] = round(stratis_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    stratis_price = stratis_price.fillna(0)
    
    stratis_price['Daily_Diff']=stratis_price['Close']-stratis_price['Open']
    stratis_price.loc[stratis_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    stratis_price.loc[stratis_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    stratis_price1 = stratis_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    stratis_price1 = stratis_price1.rename(columns={"Open": "stratis_OPEN", "High": "stratis_HIGH", "Low": "stratis_LOW", "Close": "stratis_CLOSE", "Volume": "stratis_Volume", "Market Cap": "stratis_MarketCap", "RollingAvg3_Open": "stratis_MAvg_Open", "RollingAvg3_Close": "stratis_MAvg_Close", 'Direction': "stratis_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    # waves_price
    waves_price = pd.read_csv("raw_data/waves_price.csv")
    waves_price['Name']='waves'

    # Fix Date
    waves_price['Month_Name'] = waves_price['Date'].str[:3]
    waves_price['Month_Number'] = 0
    waves_price['Date_Number'] = waves_price['Date'].str[4:6]
    waves_price['Year'] = waves_price['Date'].str[8:12]
    waves_price.loc[waves_price['Month_Name'] == "Jan", 'Month_Number'] = 1
    waves_price.loc[waves_price['Month_Name'] == "Feb", 'Month_Number'] = 2
    waves_price.loc[waves_price['Month_Name'] == "Mar", 'Month_Number'] = 3
    waves_price.loc[waves_price['Month_Name'] == "Apr", 'Month_Number'] = 4
    waves_price.loc[waves_price['Month_Name'] == "May", 'Month_Number'] = 5
    waves_price.loc[waves_price['Month_Name'] == "Jun", 'Month_Number'] = 6
    waves_price.loc[waves_price['Month_Name'] == "Jul", 'Month_Number'] = 7
    waves_price.loc[waves_price['Month_Name'] == "Aug", 'Month_Number'] = 8
    waves_price.loc[waves_price['Month_Name'] == "Sep", 'Month_Number'] = 9
    waves_price.loc[waves_price['Month_Name'] == "Oct", 'Month_Number'] = 10
    waves_price.loc[waves_price['Month_Name'] == "Nov", 'Month_Number'] = 11
    waves_price.loc[waves_price['Month_Name'] == "Dec", 'Month_Number'] = 12
    waves_price['Date_Number'] = waves_price['Date_Number'].astype(int)
    waves_price['Year'] = waves_price['Year'].astype(int)
    waves_price['New_date']=(waves_price['Year']*10000)+(waves_price['Month_Number']*100)+(waves_price['Date_Number'])
    waves_price['New_date1']=pd.to_datetime(waves_price['New_date'], format='%Y%m%d')
    waves_price = waves_price[(waves_price.New_date >= 20170221)]
    waves_price['YYYYMM']=(waves_price['Year']*100)+(waves_price['Month_Number'])

    # Sort dates
    waves_price = waves_price.sort_values(by=['Name','New_date1'])

    # Rolling Avg
    waves_price['RollingAvg3_Open'] = round(waves_price.Open.rolling(3).mean(),1)
    waves_price['RollingAvg3_Close'] = round(waves_price.Close.rolling(3).mean(),1)
    waves_price['RollingAvg7_Open'] = round(waves_price.Open.rolling(7).mean(),1)
    waves_price['RollingAvg7_Close'] = round(waves_price.Close.rolling(7).mean(),1)
    
    # Difference b/w open and close
    waves_price = waves_price.fillna(0)
    
    waves_price['Daily_Diff']=waves_price['Close']-waves_price['Open']
    waves_price.loc[waves_price['Daily_Diff'] >= 0, 'Direction'] = "Increasing"
    waves_price.loc[waves_price['Daily_Diff'] < 0, 'Direction'] = "Decreasing"
    
    # Renaming columns
    waves_price1 = waves_price[['New_date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'RollingAvg3_Open', 'RollingAvg3_Close', 'Direction' ]]
    waves_price1 = waves_price1.rename(columns={"Open": "waves_OPEN", "High": "waves_HIGH", "Low": "waves_LOW", "Close": "waves_CLOSE", "Volume": "waves_Volume", "Market Cap": "waves_MarketCap", "RollingAvg3_Open": "waves_MAvg_Open", "RollingAvg3_Close": "waves_MAvg_Close", 'Direction': "waves_Direction"})
    
    
    #----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------#
    frames = [bitcoin_cash_price,
              bitcoin_price,
              bitconnect_price,
              dash_price,
              ethereum_classic_price,
              ethereum_price,
              iota_price,
              litecoin_price,
              monero_price,
              nem_price,
              neo_price,
              numeraire_price,
              omisego_price,
              qtum_price,
              ripple_price,
              stratis_price,
              waves_price]


    price_raw = pd.concat(frames)
    #price_raw = price_raw[['New_date1','Open','Close','High','Low','Name']]
    price_raw.to_csv('price.csv')
    
    result1 = pd.merge(bitcoin_cash_price1, bitcoin_price1, how="outer", on=["New_date"])
    result2 = pd.merge(result1, bitconnect_price1, how="outer", on=["New_date"])
    result3 = pd.merge(result2, dash_price1, how = "outer", on =["New_date"])
    result4 = pd.merge(result3, ethereum_classic_price1, how = "outer", on =["New_date"])
    result5 = pd.merge(result4, ethereum_price1, how = "outer", on =["New_date"])
    result6 = pd.merge(result5, iota_price1, how = "outer", on =["New_date"])
    result7 = pd.merge(result6, litecoin_price1, how="outer", on=["New_date"])
    result8 = pd.merge(result7, monero_price1, how = "outer", on =["New_date"])
    result9 = pd.merge(result8, nem_price1, how = "outer", on =["New_date"])
    result10 = pd.merge(result9, neo_price1, how = "outer", on =["New_date"])
    result11 = pd.merge(result10, numeraire_price1, how = "outer", on =["New_date"])
    result12 = pd.merge(result11, omisego_price1, how = "outer", on =["New_date"])
    result13 = pd.merge(result12, qtum_price1, how = "outer", on =["New_date"])
    result14 = pd.merge(result13, ripple_price1, how = "outer", on =["New_date"])
    result15 = pd.merge(result14, stratis_price1, how = "outer", on =["New_date"])
    
    result = pd.merge(result15, waves_price1, how = "outer", on =["New_date"])
    
    result['New_date2']=pd.to_datetime(result['New_date'], format='%Y%m%d')
    result = result.drop(['New_date','Date_x','New_date1_x','Date_y','New_date1_y',"New_date1"], axis=1)
    result = result.rename(columns ={"New_date2": "Date"})
    #result = result.reindex(columns=column_names)
    result.to_csv('data.csv')

# %%
crptocurrency_data()

# %%
x=pd.read_csv('data.csv')
y = x[['bitcoin_cash_MAvg_Close',
       'bitcoin_MAvg_Close',
       'bitconnect_MAvg_Close',
        'dash_MAvg_Close',
       'ethereum_MAvg_Close',
       'ethereum_classic_MAvg_Close',
       'iota_MAvg_Close',
       'litecoin_MAvg_Close',
       'monero_MAvg_Close',
       'nem_MAvg_Close',
       'neo_MAvg_Close',
       'numeraire_MAvg_Close',
       'omisego_MAvg_Close',
       'qtum_MAvg_Close',
       'ripple_MAvg_Close',
       'stratis_MAvg_Close',
       'waves_MAvg_Close'
     ]]
y.to_csv('data3.csv')

# %%
y.columns
# Out:
# Index(['bitcoin_cash_MAvg_Close', 'bitcoin_MAvg_Close',
#        'bitconnect_MAvg_Close', 'dash_MAvg_Close', 'ethereum_MAvg_Close',
#        'ethereum_classic_MAvg_Close', 'iota_MAvg_Close', 'litecoin_MAvg_Close',
#        'monero_MAvg_Close', 'nem_MAvg_Close', 'neo_MAvg_Close',
#        'numeraire_MAvg_Close', 'omisego_MAvg_Close', 'qtum_MAvg_Close',
#        'ripple_MAvg_Close', 'stratis_MAvg_Close', 'waves_MAvg_Close'],
#       dtype='object')

# %%
alt.Chart(x).mark_point(size=2, opacity=0.2).encode(
    alt.X(alt.repeat("column"), type='quantitative',scale=alt.Scale(zero=False)),
    alt.Y(alt.repeat("row"), type='quantitative',scale=alt.Scale(zero=False)),
).properties(
    width=55,
    height=55
).repeat(
    row=['bitcoin_MAvg_Close'],
    column=['bitcoin_cash_MAvg_Close', 'bitcoin_MAvg_Close',
       'bitconnect_MAvg_Close', 'dash_MAvg_Close', 'ethereum_MAvg_Close',
       'ethereum_classic_MAvg_Close', 'iota_MAvg_Close', 'litecoin_MAvg_Close',
       'monero_MAvg_Close', 'nem_MAvg_Close', 'neo_MAvg_Close',
       'numeraire_MAvg_Close', 'omisego_MAvg_Close', 'qtum_MAvg_Close',
       'ripple_MAvg_Close', 'stratis_MAvg_Close', 'waves_MAvg_Close']
).configure_axis(labelFontSize=7, titleFontSize=7)
# Out:
# alt.RepeatChart(...)
